# %%
import pandas as pd

# %%
df = pd.read_csv('data9-14-9-20.csv',delimiter= ',')

# %%
df.head(5)
# Out:
#              timestamp       node_id  subsystem    sensor    parameter  \
# 0  2020/09/15 00:02:10  001e06117b45   metsense  metsense           id
# 1  2020/09/15 00:02:20  001e06117b45  chemsense       at0  temperature
# 2  2020/09/15 00:02:20  001e06117b45  chemsense       at1  temperature
# 3  2020/09/15 00:02:20  001e06117b45  chemsense       at2  temperature
# 4  2020/09/15 00:02:20  001e06117b45  chemsense       at3  temperature
#
#       value_raw     value_hrf
# 0  01d810101a00  01d810101a00
# 1        2802.0         28.02
# 2        2807.0         28.07
# 3        2819.0         28.19
# 4        2840.0          28.4

# %%
df
# Out:
#                    timestamp       node_id   subsystem           sensor  \
# 0        2020/09/15 00:02:10  001e06117b45    metsense         metsense
# 1        2020/09/15 00:02:20  001e06117b45   chemsense              at0
# 2        2020/09/15 00:02:20  001e06117b45   chemsense              at1
# 3        2020/09/15 00:02:20  001e06117b45   chemsense              at2
# 4        2020/09/15 00:02:20  001e06117b45   chemsense              at3
# 5        2020/09/15 00:02:20  001e06117b45   chemsense        chemsense
# 6        2020/09/15 00:02:20  001e06117b45   chemsense               co
# 7        2020/09/15 00:02:20  001e06117b45   chemsense              h2s
# 8        2020/09/15 00:02:20  001e06117b45   chemsense           lps25h
# 9        2020/09/15 00:02:20  001e06117b45   chemsense           lps25h
# 10       2020/09/15 00:02:20  001e06117b45   chemsense              no2
# 11       2020/09/15 00:02:20  001e06117b45   chemsense               o3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1105555 entries, 0 to 1105554
# Data columns (total 7 columns):
# timestamp    1105555 non-null object
# node_id      1105555 non-null object
# subsystem    1105555 non-null object
# sensor       1105555 non-null object
# parameter    1105555 non-null object
# value_raw    1064633 non-null object
# value_hrf    1044271 non-null object
# dtypes: object(7)
# memory usage: 59.0+ MB

# %%
df[df['sensor']=='co']['value_hrf']
# Out:
# 6          44.83956
# 60         21.11141
# 114         9.90411
# 168         3.91115
# 222         1.74886
# 276         0.28673
# 330        -0.17517
# 384        -0.51058
# 438        -0.75889
# 492        -1.23385
# 546        -1.23191
# 600        -0.94495
# 654        -1.16024
# 708        -1.04956
# 762        -1.30792
# 816        -1.09939
# 870         -1.3227
# 924         -1.4341
# 978         -1.3163
# 1032       -1.27212
# 1086       -1.50322
# 1140       -1.67094
# 1194       -1.49084
# 1248       -1.63526
# 1302       -1.41099
# 1356       -1.21256
# 1410       -1.35309
# 1464       -1.45844
# 1518       -1.69412
# 1572       -1.67558
#              ...
# 1103940    -1.18319
# 1103994    -1.29581
# 1104048    -1.44727
# 1104102    -1.33789
# 1104156    -1.16216
# 1104210    -1.03631
# 1104264    -0.97247
# 1104318    -1.08048
# 1104372    -1.36555
# 1104426    -1.45269
# 1104480    -1.48457
# 1104534    -1.39064
# 1104588    -1.45238
# 1104642    -1.28272
# ...

# %%
co_raw = df[df['sensor']=='co']
print(co_raw)
# Out:
#                   timestamp       node_id  subsystem sensor      parameter  \
# 6       2020-09-15 00:02:20  001e06117b45  chemsense     co  concentration
# 60      2020-09-15 00:02:45  001e06117b45  chemsense     co  concentration
# 114     2020-09-15 00:03:10  001e06117b45  chemsense     co  concentration
# 168     2020-09-15 00:03:36  001e06117b45  chemsense     co  concentration
# 222     2020-09-15 00:04:02  001e06117b45  chemsense     co  concentration
# 276     2020-09-15 00:04:27  001e06117b45  chemsense     co  concentration
# 330     2020-09-15 00:04:52  001e06117b45  chemsense     co  concentration
# 384     2020-09-15 00:05:13  001e06117b45  chemsense     co  concentration
# 438     2020-09-15 00:05:43  001e06117b45  chemsense     co  concentration
# 492     2020-09-15 00:06:09  001e06117b45  chemsense     co  concentration
# 546     2020-09-15 00:06:33  001e06117b45  chemsense     co  concentration
# ...

# %%
co = co_raw.loc[:,['timestamp', 'node_id', 'subsystem', 'sensor', 'parameter','value_hrf']]
print(co)
# Out:
#                   timestamp       node_id  subsystem sensor      parameter  \
# 6       2020-09-15 00:02:20  001e06117b45  chemsense     co  concentration
# 60      2020-09-15 00:02:45  001e06117b45  chemsense     co  concentration
# 114     2020-09-15 00:03:10  001e06117b45  chemsense     co  concentration
# 168     2020-09-15 00:03:36  001e06117b45  chemsense     co  concentration
# 222     2020-09-15 00:04:02  001e06117b45  chemsense     co  concentration
# 276     2020-09-15 00:04:27  001e06117b45  chemsense     co  concentration
# 330     2020-09-15 00:04:52  001e06117b45  chemsense     co  concentration
# 384     2020-09-15 00:05:13  001e06117b45  chemsense     co  concentration
# 438     2020-09-15 00:05:43  001e06117b45  chemsense     co  concentration
# 492     2020-09-15 00:06:09  001e06117b45  chemsense     co  concentration
# 546     2020-09-15 00:06:33  001e06117b45  chemsense     co  concentration
# ...

# %%
co.head()
# Out:
#               timestamp       node_id  subsystem sensor      parameter  \
# 6   2020-09-15 00:02:20  001e06117b45  chemsense     co  concentration
# 60  2020-09-15 00:02:45  001e06117b45  chemsense     co  concentration
# 114 2020-09-15 00:03:10  001e06117b45  chemsense     co  concentration
# 168 2020-09-15 00:03:36  001e06117b45  chemsense     co  concentration
# 222 2020-09-15 00:04:02  001e06117b45  chemsense     co  concentration
#
#     value_hrf
# 6    44.83956
# 60   21.11141
# 114   9.90411
# 168   3.91115
# 222   1.74886

# %%
co['moving_avg']= df['value_hrf'].rolling(window=13).mean()
co.head(30)
# Out:
#                timestamp       node_id  subsystem sensor      parameter  \
# 330  2020-09-15 00:04:52  001e06117b45  chemsense     co  concentration
# 384  2020-09-15 00:05:13  001e06117b45  chemsense     co  concentration
# 438  2020-09-15 00:05:43  001e06117b45  chemsense     co  concentration
# 492  2020-09-15 00:06:09  001e06117b45  chemsense     co  concentration
# 546  2020-09-15 00:06:33  001e06117b45  chemsense     co  concentration
# 600  2020-09-15 00:06:58  001e06117b45  chemsense     co  concentration
# 654  2020-09-15 00:07:23  001e06117b45  chemsense     co  concentration
# 708  2020-09-15 00:07:48  001e06117b45  chemsense     co  concentration
# 762  2020-09-15 00:08:14  001e06117b45  chemsense     co  concentration
# 816  2020-09-15 00:08:35  001e06117b45  chemsense     co  concentration
# 870  2020-09-15 00:09:01  001e06117b45  chemsense     co  concentration
# 924  2020-09-15 00:09:27  001e06117b45  chemsense     co  concentration
# ...

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1105555 entries, 0 to 1105554
# Data columns (total 7 columns):
# timestamp    1105555 non-null datetime64[ns]
# node_id      1105555 non-null object
# subsystem    1105555 non-null object
# sensor       1105555 non-null object
# parameter    1105555 non-null object
# value_raw    1064633 non-null object
# value_hrf    1044271 non-null object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 59.0+ MB

# %%
co = df[df['sensor']=='co']
co.info
# Out:
# <bound method DataFrame.info of                   timestamp       node_id  subsystem sensor      parameter  \
# 6       2020-09-15 00:02:20  001e06117b45  chemsense     co  concentration
# 60      2020-09-15 00:02:45  001e06117b45  chemsense     co  concentration
# 114     2020-09-15 00:03:10  001e06117b45  chemsense     co  concentration
# 168     2020-09-15 00:03:36  001e06117b45  chemsense     co  concentration
# 222     2020-09-15 00:04:02  001e06117b45  chemsense     co  concentration
# 276     2020-09-15 00:04:27  001e06117b45  chemsense     co  concentration
# 330     2020-09-15 00:04:52  001e06117b45  chemsense     co  concentration
# 384     2020-09-15 00:05:13  001e06117b45  chemsense     co  concentration
# 438     2020-09-15 00:05:43  001e06117b45  chemsense     co  concentration
# 492     2020-09-15 00:06:09  001e06117b45  chemsense     co  concentration
# 546     2020-09-15 00:06:33  001e06117b45  chemsense     co  concentration
# ...

# %%
import datetime
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
df['value_hrf'] = pd.to_numeric(df['value_hrf'],errors= 'coerce')
co = df[df['sensor']=='co']

# %%
co.plot(x = 'timestamp', y = 'value_hrf')

# %%
co = co[co['value_hrf']<0]
co.plot(x='timestamp', y= 'value_hrf')

# %%
.rolling(window=13).mean().plot(x='timestamp', y='value_hrf')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/window.py in _prep_values(self, values, kill_inf)
#     221             try:
# --> 222                 values = _ensure_float64(values)
#     223             except (ValueError, TypeError):
#
# pandas/_libs/algos_common_helper.pxi in pandas._libs.algos.ensure_float64()
#
# pandas/_libs/algos_common_helper.pxi in pandas._libs.algos.ensure_float64()
#
# ValueError: could not convert string to float: '001e06117b45'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-bfcb9231be6b> in <module>
# ----> 1 df[df['sensor']=='co'].rolling(window=13).mean().plot(x='timestamp', y='value_hrf')
#
# ...

# %%
co = co[co['value_hrf']<0]
print(co)
# Out:
#                   timestamp       node_id  subsystem sensor      parameter  \
# 330     2020-09-15 00:04:52  001e06117b45  chemsense     co  concentration
# 384     2020-09-15 00:05:13  001e06117b45  chemsense     co  concentration
# 438     2020-09-15 00:05:43  001e06117b45  chemsense     co  concentration
# 492     2020-09-15 00:06:09  001e06117b45  chemsense     co  concentration
# 546     2020-09-15 00:06:33  001e06117b45  chemsense     co  concentration
# 600     2020-09-15 00:06:58  001e06117b45  chemsense     co  concentration
# 654     2020-09-15 00:07:23  001e06117b45  chemsense     co  concentration
# 708     2020-09-15 00:07:48  001e06117b45  chemsense     co  concentration
# 762     2020-09-15 00:08:14  001e06117b45  chemsense     co  concentration
# 816     2020-09-15 00:08:35  001e06117b45  chemsense     co  concentration
# 870     2020-09-15 00:09:01  001e06117b45  chemsense     co  concentration
# ...

# %%
df
# Out:
#                   timestamp       node_id   subsystem           sensor  \
# 0       2020-09-15 00:02:10  001e06117b45    metsense         metsense
# 1       2020-09-15 00:02:20  001e06117b45   chemsense              at0
# 2       2020-09-15 00:02:20  001e06117b45   chemsense              at1
# 3       2020-09-15 00:02:20  001e06117b45   chemsense              at2
# 4       2020-09-15 00:02:20  001e06117b45   chemsense              at3
# 5       2020-09-15 00:02:20  001e06117b45   chemsense        chemsense
# 6       2020-09-15 00:02:20  001e06117b45   chemsense               co
# 7       2020-09-15 00:02:20  001e06117b45   chemsense              h2s
# 8       2020-09-15 00:02:20  001e06117b45   chemsense           lps25h
# 9       2020-09-15 00:02:20  001e06117b45   chemsense           lps25h
# 10      2020-09-15 00:02:20  001e06117b45   chemsense              no2
# 11      2020-09-15 00:02:20  001e06117b45   chemsense               o3
# ...

# %%
df[df['sensor']=='at0']['value_hrf']
# Out:
# 1          28.02
# 55         28.02
# 109        28.19
# 163        28.19
# 217        28.17
# 271        28.17
# 325        28.17
# 379        28.33
# 433        28.33
# 487        28.54
# 541        28.54
# 595        28.60
# 649        28.60
# 703        28.60
# 757        28.58
# 811        28.93
# 865        28.93
# 919        28.93
# 973        29.14
# 1027       29.14
# 1081       29.16
# 1135       29.16
# 1189       29.13
# 1243       29.13
# 1297       29.13
# 1351       29.22
# 1405       29.22
# 1459       29.03
# 1513       29.03
# 1567       28.89
#            ...
# 1103935    24.31
# 1103989    24.31
# 1104043    24.31
# 1104097    24.31
# 1104151    24.31
# 1104205    24.33
# 1104259    24.33
# 1104313    24.33
# 1104367    24.32
# 1104421    24.32
# 1104475    24.25
# 1104529    24.25
# 1104583    24.18
# 1104637    24.18
# 1104691    24.18
# 1104745    24.09
# 1104799    24.09
# 1104853    24.13
# 1104907    24.13
# 1104961    24.12
# 1105015    24.12
# ...

# %%
temps = df[df['sensor']=='at0']
print(temps)
# Out:
#                   timestamp       node_id  subsystem sensor    parameter  \
# 1       2020-09-15 00:02:20  001e06117b45  chemsense    at0  temperature
# 55      2020-09-15 00:02:45  001e06117b45  chemsense    at0  temperature
# 109     2020-09-15 00:03:10  001e06117b45  chemsense    at0  temperature
# 163     2020-09-15 00:03:36  001e06117b45  chemsense    at0  temperature
# 217     2020-09-15 00:04:02  001e06117b45  chemsense    at0  temperature
# 271     2020-09-15 00:04:27  001e06117b45  chemsense    at0  temperature
# 325     2020-09-15 00:04:52  001e06117b45  chemsense    at0  temperature
# 379     2020-09-15 00:05:13  001e06117b45  chemsense    at0  temperature
# 433     2020-09-15 00:05:43  001e06117b45  chemsense    at0  temperature
# 487     2020-09-15 00:06:09  001e06117b45  chemsense    at0  temperature
# 541     2020-09-15 00:06:33  001e06117b45  chemsense    at0  temperature
# 595     2020-09-15 00:06:58  001e06117b45  chemsense    at0  temperature
# ...

# %%
temps['moving_avg']= df['value_hrf'].rolling(window=13).mean()
temps.head(30)
# Out:
# /Users/shi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                timestamp       node_id  subsystem sensor    parameter  \
# 1    2020-09-15 00:02:20  001e06117b45  chemsense    at0  temperature
# 55   2020-09-15 00:02:45  001e06117b45  chemsense    at0  temperature
# 109  2020-09-15 00:03:10  001e06117b45  chemsense    at0  temperature
# 163  2020-09-15 00:03:36  001e06117b45  chemsense    at0  temperature
# 217  2020-09-15 00:04:02  001e06117b45  chemsense    at0  temperature
# 271  2020-09-15 00:04:27  001e06117b45  chemsense    at0  temperature
# 325  2020-09-15 00:04:52  001e06117b45  chemsense    at0  temperature
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1105555 entries, 0 to 1105554
# Data columns (total 7 columns):
# timestamp    1105555 non-null datetime64[ns]
# node_id      1105555 non-null object
# subsystem    1105555 non-null object
# sensor       1105555 non-null object
# parameter    1105555 non-null object
# value_raw    1064633 non-null object
# value_hrf    1003348 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 59.0+ MB

# %%
temps = df[df['sensor']=='at0']
temps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20428 entries, 1 to 1105501
# Data columns (total 7 columns):
# timestamp    20428 non-null datetime64[ns]
# node_id      20428 non-null object
# subsystem    20428 non-null object
# sensor       20428 non-null object
# parameter    20428 non-null object
# value_raw    20428 non-null object
# value_hrf    20428 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 1.2+ MB

# %%
df['value_hrf'] = pd.to_numeric(df['value_hrf'], errors='coerce')
temps = df[df['sensor']=='at0']

# %%
temps.plot(x= 'timestamp', y= 'value_hrf')

# %%
temps.plot

# %%
df
# Out:
#                   timestamp       node_id   subsystem           sensor  \
# 0       2020-09-15 00:02:10  001e06117b45    metsense         metsense
# 1       2020-09-15 00:02:20  001e06117b45   chemsense              at0
# 2       2020-09-15 00:02:20  001e06117b45   chemsense              at1
# 3       2020-09-15 00:02:20  001e06117b45   chemsense              at2
# 4       2020-09-15 00:02:20  001e06117b45   chemsense              at3
# 5       2020-09-15 00:02:20  001e06117b45   chemsense        chemsense
# 6       2020-09-15 00:02:20  001e06117b45   chemsense               co
# 7       2020-09-15 00:02:20  001e06117b45   chemsense              h2s
# 8       2020-09-15 00:02:20  001e06117b45   chemsense           lps25h
# 9       2020-09-15 00:02:20  001e06117b45   chemsense           lps25h
# 10      2020-09-15 00:02:20  001e06117b45   chemsense              no2
# 11      2020-09-15 00:02:20  001e06117b45   chemsense               o3
# ...

# %%
df[df['sensor']=='hih4030']['value_hrf']
# Out:
# 31         77.06
# 85         74.66
# 139        75.71
# 193        75.86
# 247        72.27
# 301        75.11
# 355        72.56
# 409        72.86
# 463        76.61
# 517        75.11
# 571        73.61
# 625        68.52
# 679        72.71
# 733        73.01
# 787        75.11
# 841        73.31
# 895        75.41
# 949        76.16
# 1003       75.41
# 1057       72.12
# 1111       74.96
# 1165       76.61
# 1219       73.31
# 1273       72.27
# 1327       75.26
# 1381       74.66
# 1435       75.86
# 1489       75.56
# 1543       74.96
# 1597       72.41
#            ...
# 1103965    70.32
# 1104019    69.72
# 1104073    70.17
# 1104127    70.32
# 1104181    70.47
# 1104235    70.62
# 1104289    72.71
# 1104343    69.12
# 1104397    70.47
# 1104451    69.72
# 1104505    70.47
# 1104559    70.92
# 1104613    70.92
# 1104667    70.32
# 1104721    71.07
# 1104775    70.32
# 1104829    71.37
# 1104883    70.62
# 1104937    70.77
# 1104991    72.71
# 1105045    71.37
# ...

# %%
hum  = df[df['sensor']=='hih4030']
print(hum)
# Out:
#                   timestamp       node_id subsystem   sensor parameter  \
# 31      2020-09-15 00:02:20  001e06117b45  metsense  hih4030  humidity
# 85      2020-09-15 00:02:45  001e06117b45  metsense  hih4030  humidity
# 139     2020-09-15 00:03:10  001e06117b45  metsense  hih4030  humidity
# 193     2020-09-15 00:03:36  001e06117b45  metsense  hih4030  humidity
# 247     2020-09-15 00:04:02  001e06117b45  metsense  hih4030  humidity
# 301     2020-09-15 00:04:27  001e06117b45  metsense  hih4030  humidity
# 355     2020-09-15 00:04:52  001e06117b45  metsense  hih4030  humidity
# 409     2020-09-15 00:05:13  001e06117b45  metsense  hih4030  humidity
# 463     2020-09-15 00:05:43  001e06117b45  metsense  hih4030  humidity
# 517     2020-09-15 00:06:09  001e06117b45  metsense  hih4030  humidity
# 571     2020-09-15 00:06:33  001e06117b45  metsense  hih4030  humidity
# 625     2020-09-15 00:06:58  001e06117b45  metsense  hih4030  humidity
# ...

# %%
hum['moving_avg']= df['value_hrf'].rolling(window=13).mean()
hum.head(30)
# Out:
# /Users/shi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                timestamp       node_id subsystem   sensor parameter value_raw  \
# 31   2020-09-15 00:02:20  001e06117b45  metsense  hih4030  humidity       508
# 85   2020-09-15 00:02:45  001e06117b45  metsense  hih4030  humidity       492
# 139  2020-09-15 00:03:10  001e06117b45  metsense  hih4030  humidity       499
# 193  2020-09-15 00:03:36  001e06117b45  metsense  hih4030  humidity       500
# 247  2020-09-15 00:04:02  001e06117b45  metsense  hih4030  humidity       476
# 301  2020-09-15 00:04:27  001e06117b45  metsense  hih4030  humidity       495
# ...

# %%
hum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20494 entries, 31 to 1105531
# Data columns (total 7 columns):
# timestamp    20494 non-null datetime64[ns]
# node_id      20494 non-null object
# subsystem    20494 non-null object
# sensor       20494 non-null object
# parameter    20494 non-null object
# value_raw    20494 non-null object
# value_hrf    20494 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 1.3+ MB

# %%
df['value_hrf'] = pd.to_numeric(df['value_hrf'], errors='coerce')
hum = df[df['sensor']=='hih4030']

# %%
hum.plot(x= 'timestamp', y='value_hrf')

# %%
display(hum)
display(co)
display(temps)
# Out:
#                   timestamp       node_id subsystem   sensor parameter  \
# 31      2020-09-15 00:02:20  001e06117b45  metsense  hih4030  humidity
# 85      2020-09-15 00:02:45  001e06117b45  metsense  hih4030  humidity
# 139     2020-09-15 00:03:10  001e06117b45  metsense  hih4030  humidity
# 193     2020-09-15 00:03:36  001e06117b45  metsense  hih4030  humidity
# 247     2020-09-15 00:04:02  001e06117b45  metsense  hih4030  humidity
# 301     2020-09-15 00:04:27  001e06117b45  metsense  hih4030  humidity
# 355     2020-09-15 00:04:52  001e06117b45  metsense  hih4030  humidity
# 409     2020-09-15 00:05:13  001e06117b45  metsense  hih4030  humidity
# 463     2020-09-15 00:05:43  001e06117b45  metsense  hih4030  humidity
# 517     2020-09-15 00:06:09  001e06117b45  metsense  hih4030  humidity
# 571     2020-09-15 00:06:33  001e06117b45  metsense  hih4030  humidity
# 625     2020-09-15 00:06:58  001e06117b45  metsense  hih4030  humidity
# ...

# %%
dffinal = (hum, co, temps)

# %%
dffinal
# Out:
# (                  timestamp       node_id subsystem   sensor parameter  \
#  31      2020-09-15 00:02:20  001e06117b45  metsense  hih4030  humidity
#  85      2020-09-15 00:02:45  001e06117b45  metsense  hih4030  humidity
#  139     2020-09-15 00:03:10  001e06117b45  metsense  hih4030  humidity
#  193     2020-09-15 00:03:36  001e06117b45  metsense  hih4030  humidity
#  247     2020-09-15 00:04:02  001e06117b45  metsense  hih4030  humidity
#  301     2020-09-15 00:04:27  001e06117b45  metsense  hih4030  humidity
#  355     2020-09-15 00:04:52  001e06117b45  metsense  hih4030  humidity
#  409     2020-09-15 00:05:13  001e06117b45  metsense  hih4030  humidity
#  463     2020-09-15 00:05:43  001e06117b45  metsense  hih4030  humidity
#  517     2020-09-15 00:06:09  001e06117b45  metsense  hih4030  humidity
#  571     2020-09-15 00:06:33  001e06117b45  metsense  hih4030  humidity
#  625     2020-09-15 00:06:58  001e06117b45  metsense  hih4030  humidity
# ...

# %%
co.to_csv('AoT data 09-14 to 09-20', encoding='utf-8', index= False)
